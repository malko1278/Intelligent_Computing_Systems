# %%
# Интеллектуальные вычислительные системы
# АБЕНА Армель Фрэнк Малько 420-М1
# Лабораторная работа №1
# Вариант 2
# Функция: z= cos(x) + sin(y – p/2)
# x --> (-p <=x<= p)
# y --> (-p <=y<= p)
# z --> (-2 <=z<= 2)

# %%
# Импорт книготорговцев
# !pip install -U scikit-fuzzy

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import skfuzzy as fuzz
from skfuzzy import control as ctrl
# Out:
# Requirement already satisfied: scikit-fuzzy in /home/franck-malko/anaconda3/lib/python3.9/site-packages (0.4.2)
# Requirement already satisfied: scipy>=0.9.0 in /home/franck-malko/anaconda3/lib/python3.9/site-packages (from scikit-fuzzy) (1.7.1)
# Requirement already satisfied: numpy>=1.6.0 in /home/franck-malko/anaconda3/lib/python3.9/site-packages (from scikit-fuzzy) (1.20.3)
# Requirement already satisfied: networkx>=1.9.0 in /home/franck-malko/anaconda3/lib/python3.9/site-packages (from scikit-fuzzy) (2.6.3)

# %%
fix, ax = plt.subplots(subplot_kw={"projection": "3d"})
X = np.arange(-math.pi, math.pi, 0.25)
Y = np.arange(-math.pi, math.pi, 0.25)
X, Y = np.meshgrid(X, Y)
z = np.cos(X) + np.sin(Y - (math.pi/2))     # z= cos(x) + sin(y – p/2)
surface = ax.plot_surface(X,Y,z)
ax.set_zlim()
plt.title('График функции')
plt.show(-2, 2)

# %%
# Множества термов
terms5 = [
          'очень малая',
          'малая',
          'средняя',
          'большая',
          'очень большая'
]

terms7 = [
          'сильно малая',
          'очень малая',
          'малая',
          'средняя',
          'большая',
          'очень большая',
          'сильно большая'
]

terms9 = [
          'сильно малая',
          'очень малая',
          'малая',
          'ниже среднего',
          'средняя',
          'выше среднего',
          'большая',
          'очень большая',
          'сильно большая'
]

terms11 = [
           'сильно малая',
           'очень малая',
           'малая',
           'выше малой',
           'ниже среднего',
           'средняя',
           'выше среднего',
           'ниже большой',
           'большая',
           'очень большая',
           'сильно большая'
]

# %%
def intervals(start, end, num_terms):
  terms = []
  if num_terms == 5:
    terms = terms5
  elif num_terms == 7:
    terms = terms7
  elif num_terms == 9:
    terms = terms9
  elif num_terms == 11:
    terms = terms11
  
  step = (abs(start) + abs(end)) / (num_terms)
  
  print("{} термов:".format(num_terms))
  for i in range(num_terms):
    print("{} на отрезке от {:.2f} до {:.2f}".format(terms[i], start + step * i, start + step * (i+1)))

# %%
print("\033[1m" + "Данные для построения ФП X:" + "\033[0m")
for i in [5, 7, 9, 11]:
  intervals(-math.pi, math.pi, i)
# Out:
# Данные для построения ФП X:
# 5 термов:
# очень малая на отрезке от -3.14 до -1.88
# малая на отрезке от -1.88 до -0.63
# средняя на отрезке от -0.63 до 0.63
# большая на отрезке от 0.63 до 1.88
# очень большая на отрезке от 1.88 до 3.14
# 7 термов:
# сильно малая на отрезке от -3.14 до -2.24
# очень малая на отрезке от -2.24 до -1.35
# малая на отрезке от -1.35 до -0.45
# средняя на отрезке от -0.45 до 0.45
# большая на отрезке от 0.45 до 1.35
# очень большая на отрезке от 1.35 до 2.24
# сильно большая на отрезке от 2.24 до 3.14
# 9 термов:
# сильно малая на отрезке от -3.14 до -2.44
# очень малая на отрезке от -2.44 до -1.75
# малая на отрезке от -1.75 до -1.05
# ниже среднего на отрезке от -1.05 до -0.35
# средняя на отрезке от -0.35 до 0.35
# выше среднего на отрезке от 0.35 до 1.05
# большая на отрезке от 1.05 до 1.75
# очень большая на отрезке от 1.75 до 2.44
# сильно большая на отрезке от 2.44 до 3.14
# 11 термов:
# сильно малая на отрезке от -3.14 до -2.57
# очень малая на отрезке от -2.57 до -2.00
# малая на отрезке от -2.00 до -1.43
# выше малой на отрезке от -1.43 до -0.86
# ниже среднего на отрезке от -0.86 до -0.29
# средняя на отрезке от -0.29 до 0.29
# выше среднего на отрезке от 0.29 до 0.86
# ниже большой на отрезке от 0.86 до 1.43
# большая на отрезке от 1.43 до 2.00
# очень большая на отрезке от 2.00 до 2.57
# сильно большая на отрезке от 2.57 до 3.14

# %%
print("\033[1m" + "Данные для построения ФП Y:" + "\033[0m")
for i in [5, 7, 9, 11]:
  intervals(-math.pi, math.pi, i)
# Out:
# Данные для построения ФП Y:
# 5 термов:
# очень малая на отрезке от -3.14 до -1.88
# малая на отрезке от -1.88 до -0.63
# средняя на отрезке от -0.63 до 0.63
# большая на отрезке от 0.63 до 1.88
# очень большая на отрезке от 1.88 до 3.14
# 7 термов:
# сильно малая на отрезке от -3.14 до -2.24
# очень малая на отрезке от -2.24 до -1.35
# малая на отрезке от -1.35 до -0.45
# средняя на отрезке от -0.45 до 0.45
# большая на отрезке от 0.45 до 1.35
# очень большая на отрезке от 1.35 до 2.24
# сильно большая на отрезке от 2.24 до 3.14
# 9 термов:
# сильно малая на отрезке от -3.14 до -2.44
# очень малая на отрезке от -2.44 до -1.75
# малая на отрезке от -1.75 до -1.05
# ниже среднего на отрезке от -1.05 до -0.35
# средняя на отрезке от -0.35 до 0.35
# выше среднего на отрезке от 0.35 до 1.05
# большая на отрезке от 1.05 до 1.75
# очень большая на отрезке от 1.75 до 2.44
# сильно большая на отрезке от 2.44 до 3.14
# 11 термов:
# сильно малая на отрезке от -3.14 до -2.57
# очень малая на отрезке от -2.57 до -2.00
# малая на отрезке от -2.00 до -1.43
# выше малой на отрезке от -1.43 до -0.86
# ниже среднего на отрезке от -0.86 до -0.29
# средняя на отрезке от -0.29 до 0.29
# выше среднего на отрезке от 0.29 до 0.86
# ниже большой на отрезке от 0.86 до 1.43
# большая на отрезке от 1.43 до 2.00
# очень большая на отрезке от 2.00 до 2.57
# сильно большая на отрезке от 2.57 до 3.14

# %%
print("\033[1m" + "Данные для построения ФП Z:" + "\033[0m")
for i in [5, 7, 9, 11]:
  intervals(-2, 2, i)
# Out:
# Данные для построения ФП Z:
# 5 термов:
# очень малая на отрезке от -2.00 до -1.20
# малая на отрезке от -1.20 до -0.40
# средняя на отрезке от -0.40 до 0.40
# большая на отрезке от 0.40 до 1.20
# очень большая на отрезке от 1.20 до 2.00
# 7 термов:
# сильно малая на отрезке от -2.00 до -1.43
# очень малая на отрезке от -1.43 до -0.86
# малая на отрезке от -0.86 до -0.29
# средняя на отрезке от -0.29 до 0.29
# большая на отрезке от 0.29 до 0.86
# очень большая на отрезке от 0.86 до 1.43
# сильно большая на отрезке от 1.43 до 2.00
# 9 термов:
# сильно малая на отрезке от -2.00 до -1.56
# очень малая на отрезке от -1.56 до -1.11
# малая на отрезке от -1.11 до -0.67
# ниже среднего на отрезке от -0.67 до -0.22
# средняя на отрезке от -0.22 до 0.22
# выше среднего на отрезке от 0.22 до 0.67
# большая на отрезке от 0.67 до 1.11
# очень большая на отрезке от 1.11 до 1.56
# сильно большая на отрезке от 1.56 до 2.00
# 11 термов:
# сильно малая на отрезке от -2.00 до -1.64
# очень малая на отрезке от -1.64 до -1.27
# малая на отрезке от -1.27 до -0.91
# выше малой на отрезке от -0.91 до -0.55
# ниже среднего на отрезке от -0.55 до -0.18
# средняя на отрезке от -0.18 до 0.18
# выше среднего на отрезке от 0.18 до 0.55
# ниже большой на отрезке от 0.55 до 0.91
# большая на отрезке от 0.91 до 1.27
# очень большая на отрезке от 1.27 до 1.64
# сильно большая на отрезке от 1.64 до 2.00

# %%
def rules(start, end, num_terms, label):
  terms = []
  if num_terms == 5:
    terms = terms5
  elif num_terms == 7:
    terms = terms7
  elif num_terms == 9:
    terms = terms9
  elif num_terms == 11:
    terms = terms11

  step = (abs(start) + abs(end)) / num_terms
  func = ctrl.Antecedent(np.arange(start, end + step, step), label)
  ranges = [None] * num_terms
  for i in np.arange(0, num_terms, 1):
    triangle = []
    if i == 0:
      triangle = [start, start, start + step]
      ranges[i] = {}
      ranges[i]['start'] = triangle[1]
      ranges[i]['end'] = triangle[2] - (step / 2)
    else:
      triangle = [
                  (i - 1) * step - abs(start),
                  i * step - abs(start),
                  (i + 1) * step - abs(start)
      ]
      if num_terms - 1 == i:
        ranges[i] = {}
        ranges[i]['start'] = triangle[0] + (step / 2)
        ranges[i]['end'] = triangle[1]
      else:
        ranges[i] = {}
        ranges[i]['start'] = triangle[0] + (step / 2)
        ranges[i]['end'] = triangle[2] - (step / 2)
    ranges[i]['term'] = terms[i]
    func[terms[i]] = fuzz.trimf(func.universe, triangle)
  func.view()
  return ranges

# %%
print('ФП Х при 5 термах')
rules(-math.pi, math.pi, 5, 'ФП Х при 5 термах')
# Out:
# ФП Х при 5 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.5132741228718345,
#   'term': 'очень малая'},
#  {'start': -2.5132741228718345, 'end': -1.2566370614359172, 'term': 'малая'},
#  {'start': -1.2566370614359172, 'end': 0.0, 'term': 'средняя'},
#  {'start': 0.0, 'end': 1.2566370614359172, 'term': 'большая'},
#  {'start': 1.2566370614359172,
#   'end': 1.8849555921538759,
#   'term': 'очень большая'}]

# %%
print('ФП Х при 7 термах')
rules(-math.pi, math.pi, 7, 'ФП Х при 7 термах')
# Out:
# ФП Х при 7 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.6927937030769655,
#   'term': 'сильно малая'},
#  {'start': -2.6927937030769655,
#   'end': -1.7951958020513104,
#   'term': 'очень малая'},
#  {'start': -1.7951958020513104, 'end': -0.8975979010256552, 'term': 'малая'},
#  {'start': -0.8975979010256552, 'end': 0.0, 'term': 'средняя'},
#  {'start': 0.0, 'end': 0.8975979010256552, 'term': 'большая'},
#  {'start': 0.8975979010256552,
#   'end': 1.7951958020513104,
#   'term': 'очень большая'},
#  {'start': 1.7951958020513104,
#   'end': 2.243994752564138,
#   'term': 'сильно большая'}]

# %%
print('ФП Х при 9 термах')
rules(-math.pi, math.pi, 9, 'ФП Х при 9 термах')
# Out:
# ФП Х при 9 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.792526803190927,
#   'term': 'сильно малая'},
#  {'start': -2.792526803190927,
#   'end': -2.0943951023931953,
#   'term': 'очень малая'},
#  {'start': -2.0943951023931953, 'end': -1.3962634015954638, 'term': 'малая'},
#  {'start': -1.3962634015954636,
#   'end': -0.6981317007977319,
#   'term': 'ниже среднего'},
#  {'start': -0.6981317007977319,
#   'end': 5.551115123125783e-17,
#   'term': 'средняя'},
#  {'start': -5.551115123125783e-17,
#   'end': 0.6981317007977315,
#   'term': 'выше среднего'},
#  {'start': 0.6981317007977319, 'end': 1.3962634015954634, 'term': 'большая'},
#  {'start': 1.3962634015954634,
#   'end': 2.0943951023931953,
#   'term': 'очень большая'},
#  {'start': 2.0943951023931953,
#   'end': 2.443460952792061,
#   'term': 'сильно большая'}]

# %%
print('ФП Х при 11 термах')
rules(-math.pi, math.pi, 11, 'ФП Х при 11 термах')
# Out:
# ФП Х при 11 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.855993321445266,
#   'term': 'сильно малая'},
#  {'start': -2.8559933214452666,
#   'end': -2.284794657156213,
#   'term': 'очень малая'},
#  {'start': -2.284794657156213, 'end': -1.71359599286716, 'term': 'малая'},
#  {'start': -1.7135959928671598,
#   'end': -1.1423973285781066,
#   'term': 'выше малой'},
#  {'start': -1.1423973285781066,
#   'end': -0.5711986642890532,
#   'term': 'ниже среднего'},
#  {'start': -0.5711986642890532,
#   'end': -1.6653345369377348e-16,
#   'term': 'средняя'},
#  {'start': 1.6653345369377348e-16,
#   'end': 0.5711986642890532,
#   'term': 'выше среднего'},
#  {'start': 0.5711986642890532,
#   'end': 1.1423973285781066,
#   'term': 'ниже большой'},
#  {'start': 1.1423973285781066, 'end': 1.7135959928671596, 'term': 'большая'},
#  {'start': 1.71359599286716,
#   'end': 2.2847946571562137,
#   'term': 'очень большая'},
#  {'start': 2.2847946571562128,
#   'end': 2.57039398930074,
#   'term': 'сильно большая'}]

# %%
print('ФП Y при 5 термах')
rules(-math.pi, math.pi, 5, 'ФП Y при 5 термах')
# Out:
# ФП Y при 5 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.5132741228718345,
#   'term': 'очень малая'},
#  {'start': -2.5132741228718345, 'end': -1.2566370614359172, 'term': 'малая'},
#  {'start': -1.2566370614359172, 'end': 0.0, 'term': 'средняя'},
#  {'start': 0.0, 'end': 1.2566370614359172, 'term': 'большая'},
#  {'start': 1.2566370614359172,
#   'end': 1.8849555921538759,
#   'term': 'очень большая'}]

# %%
print('ФП Y при 7 термах')
rules(-math.pi, math.pi, 7, 'ФП Y при 7 термах')
# Out:
# ФП Y при 7 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.6927937030769655,
#   'term': 'сильно малая'},
#  {'start': -2.6927937030769655,
#   'end': -1.7951958020513104,
#   'term': 'очень малая'},
#  {'start': -1.7951958020513104, 'end': -0.8975979010256552, 'term': 'малая'},
#  {'start': -0.8975979010256552, 'end': 0.0, 'term': 'средняя'},
#  {'start': 0.0, 'end': 0.8975979010256552, 'term': 'большая'},
#  {'start': 0.8975979010256552,
#   'end': 1.7951958020513104,
#   'term': 'очень большая'},
#  {'start': 1.7951958020513104,
#   'end': 2.243994752564138,
#   'term': 'сильно большая'}]

# %%
print('ФП Y при 9 термах')
rules(-math.pi, math.pi, 9, 'ФП Y при 9 термах')
# Out:
# ФП Y при 9 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.792526803190927,
#   'term': 'сильно малая'},
#  {'start': -2.792526803190927,
#   'end': -2.0943951023931953,
#   'term': 'очень малая'},
#  {'start': -2.0943951023931953, 'end': -1.3962634015954638, 'term': 'малая'},
#  {'start': -1.3962634015954636,
#   'end': -0.6981317007977319,
#   'term': 'ниже среднего'},
#  {'start': -0.6981317007977319,
#   'end': 5.551115123125783e-17,
#   'term': 'средняя'},
#  {'start': -5.551115123125783e-17,
#   'end': 0.6981317007977315,
#   'term': 'выше среднего'},
#  {'start': 0.6981317007977319, 'end': 1.3962634015954634, 'term': 'большая'},
#  {'start': 1.3962634015954634,
#   'end': 2.0943951023931953,
#   'term': 'очень большая'},
#  {'start': 2.0943951023931953,
#   'end': 2.443460952792061,
#   'term': 'сильно большая'}]

# %%
print('ФП Y при 11 термах')
rules(-math.pi, math.pi, 11, 'ФП Y при 11 термах')
# Out:
# ФП Y при 11 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -3.141592653589793,
#   'end': -2.855993321445266,
#   'term': 'сильно малая'},
#  {'start': -2.8559933214452666,
#   'end': -2.284794657156213,
#   'term': 'очень малая'},
#  {'start': -2.284794657156213, 'end': -1.71359599286716, 'term': 'малая'},
#  {'start': -1.7135959928671598,
#   'end': -1.1423973285781066,
#   'term': 'выше малой'},
#  {'start': -1.1423973285781066,
#   'end': -0.5711986642890532,
#   'term': 'ниже среднего'},
#  {'start': -0.5711986642890532,
#   'end': -1.6653345369377348e-16,
#   'term': 'средняя'},
#  {'start': 1.6653345369377348e-16,
#   'end': 0.5711986642890532,
#   'term': 'выше среднего'},
#  {'start': 0.5711986642890532,
#   'end': 1.1423973285781066,
#   'term': 'ниже большой'},
#  {'start': 1.1423973285781066, 'end': 1.7135959928671596, 'term': 'большая'},
#  {'start': 1.71359599286716,
#   'end': 2.2847946571562137,
#   'term': 'очень большая'},
#  {'start': 2.2847946571562128,
#   'end': 2.57039398930074,
#   'term': 'сильно большая'}]

# %%
print('ФП Z при 5 термах')
rules(-2, 2, 5, 'ФП Z при 5 термах')
# Out:
# ФП Z при 5 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -2, 'end': -1.6, 'term': 'очень малая'},
#  {'start': -1.6, 'end': -0.7999999999999999, 'term': 'малая'},
#  {'start': -0.7999999999999999,
#   'end': 3.3306690738754696e-16,
#   'term': 'средняя'},
#  {'start': 1.1102230246251565e-16,
#   'end': 0.8000000000000002,
#   'term': 'большая'},
#  {'start': 0.8000000000000004,
#   'end': 1.2000000000000002,
#   'term': 'очень большая'}]

# %%
print('ФП Z при 7 термах')
rules(-2, 2, 7, 'ФП Z при 7 термах')
# Out:
# ФП Z при 7 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -2, 'end': -1.7142857142857144, 'term': 'сильно малая'},
#  {'start': -1.7142857142857144,
#   'end': -1.1428571428571428,
#   'term': 'очень малая'},
#  {'start': -1.1428571428571428, 'end': -0.5714285714285715, 'term': 'малая'},
#  {'start': -0.5714285714285715,
#   'end': -1.1102230246251565e-16,
#   'term': 'средняя'},
#  {'start': -1.1102230246251565e-16,
#   'end': 0.5714285714285711,
#   'term': 'большая'},
#  {'start': 0.5714285714285713,
#   'end': 1.1428571428571428,
#   'term': 'очень большая'},
#  {'start': 1.1428571428571423,
#   'end': 1.4285714285714284,
#   'term': 'сильно большая'}]

# %%
print('ФП Z при 9 термах')
rules(-2, 2, 9, 'ФП Z при 9 термах')
# Out:
# ФП Z при 9 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -2, 'end': -1.7777777777777777, 'term': 'сильно малая'},
#  {'start': -1.7777777777777777,
#   'end': -1.3333333333333335,
#   'term': 'очень малая'},
#  {'start': -1.3333333333333335, 'end': -0.888888888888889, 'term': 'малая'},
#  {'start': -0.888888888888889,
#   'end': -0.44444444444444453,
#   'term': 'ниже среднего'},
#  {'start': -0.44444444444444453,
#   'end': 1.1102230246251565e-16,
#   'term': 'средняя'},
#  {'start': -1.1102230246251565e-16,
#   'end': 0.4444444444444443,
#   'term': 'выше среднего'},
#  {'start': 0.44444444444444453, 'end': 0.8888888888888885, 'term': 'большая'},
#  {'start': 0.8888888888888887,
#   'end': 1.333333333333333,
#   'term': 'очень большая'},
#  {'start': 1.333333333333333,
#   'end': 1.5555555555555554,
#   'term': 'сильно большая'}]

# %%
print('ФП Z при 11 термах')
rules(-2, 2, 11, 'ФП Z при 11 термах')
# Out:
# ФП Z при 11 термах
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# [{'start': -2, 'end': -1.8181818181818181, 'term': 'сильно малая'},
#  {'start': -1.8181818181818181,
#   'end': -1.4545454545454546,
#   'term': 'очень малая'},
#  {'start': -1.4545454545454544, 'end': -1.090909090909091, 'term': 'малая'},
#  {'start': -1.0909090909090908,
#   'end': -0.7272727272727273,
#   'term': 'выше малой'},
#  {'start': -0.7272727272727273,
#   'end': -0.3636363636363635,
#   'term': 'ниже среднего'},
#  {'start': -0.3636363636363636,
#   'end': -1.6653345369377348e-16,
#   'term': 'средняя'},
#  {'start': 1.6653345369377348e-16,
#   'end': 0.3636363636363636,
#   'term': 'выше среднего'},
#  {'start': 0.3636363636363635,
#   'end': 0.7272727272727273,
#   'term': 'ниже большой'},
#  {'start': 0.7272727272727273, 'end': 1.090909090909091, 'term': 'большая'},
#  {'start': 1.090909090909091,
#   'end': 1.4545454545454548,
#   'term': 'очень большая'},
#  {'start': 1.4545454545454548,
#   'end': 1.6363636363636367,
#   'term': 'сильно большая'}]

# %%
rangesX_5 = rules(-math.pi, math.pi, 5, 'Х - 5')
rangesX_7 = rules(-math.pi, math.pi, 7, 'Х - 7')
rangesX_9 = rules(-math.pi, math.pi, 9, 'Х - 9')
rangesX_11 = rules(-math.pi, math.pi, 11, 'Х - 11')
# Out:
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rangesY_5 = rules(-math.pi, math.pi, 5, 'Y - 5')
rangesY_7 = rules(-math.pi, math.pi, 7, 'Y - 7')
rangesY_9 = rules(-math.pi, math.pi, 9, 'Y - 9')
rangesY_11 = rules(-math.pi, math.pi, 11, 'Y - 11')
# Out:
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rangesZ_5 = rules(-2, 2, 5, 'Z - 5')
rangesZ_7 = rules(-2, 2, 7, 'Z - 7')
rangesZ_9 = rules(-2, 2, 9, 'Z - 9')
rangesZ_11 = rules(-2, 2, 11, 'Z - 11')
# Out:
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/franck-malko/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
print("\033[1m" + "Мамдани для 5 термов" + "\033[0m")
for rangeX in rangesX_5:
  for rangeY in rangesY_5:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_5:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], rangeZ['term']))
# Out:
# Мамдани для 5 термов
# Если х = очень малая и y = очень малая то F= очень малая
# Если х = очень малая и y = малая то F= очень малая
# Если х = очень малая и y = средняя то F= средняя
# Если х = очень малая и y = большая то F= средняя
# Если х = очень малая и y = очень большая то F= малая
# Если х = малая и y = малая то F= малая
# Если х = малая и y = средняя то F= большая
# Если х = малая и y = большая то F= средняя
# Если х = малая и y = очень большая то F= средняя
# Если х = средняя и y = очень малая то F= малая
# Если х = средняя и y = малая то F= очень большая
# Если х = средняя и y = средняя то F= большая
# Если х = средняя и y = большая то F= средняя
# Если х = большая и y = средняя то F= средняя
# Если х = большая и y = большая то F= большая
# Если х = очень большая и y = малая то F= большая
# Если х = очень большая и y = средняя то F= средняя
# Если х = очень большая и y = большая то F= большая
# Если х = очень большая и y = очень большая то F= средняя
# Если х = очень большая и y = очень большая то F= большая

# %%
print("\033[1m" + "Мамдани для 7 термов" + "\033[0m")
for rangeX in rangesX_7:
  for rangeY in rangesY_7:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_7:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], rangeZ['term']))
# Out:
# Мамдани для 7 термов
# Если х = сильно малая и y = сильно малая то F= очень малая
# Если х = сильно малая и y = малая то F= очень малая
# Если х = сильно малая и y = средняя то F= средняя
# Если х = сильно малая и y = большая то F= средняя
# Если х = сильно малая и y = очень большая то F= очень малая
# Если х = сильно малая и y = сильно большая то F= очень малая
# Если х = очень малая и y = малая то F= малая
# Если х = очень малая и y = средняя то F= большая
# Если х = очень малая и y = большая то F= средняя
# Если х = очень малая и y = очень большая то F= малая
# Если х = очень малая и y = сильно большая то F= средняя
# Если х = малая и y = очень малая то F= малая
# Если х = малая и y = малая то F= очень большая
# Если х = малая и y = средняя то F= большая
# Если х = малая и y = большая то F= средняя
# Если х = малая и y = очень большая то F= большая
# Если х = малая и y = сильно большая то F= сильно большая
# Если х = средняя и y = сильно малая то F= малая
# Если х = средняя и y = очень малая то F= очень большая
# Если х = средняя и y = малая то F= сильно большая
# Если х = средняя и y = средняя то F= большая
# Если х = средняя и y = большая то F= большая
# Если х = средняя и y = очень большая то F= очень большая
# Если х = большая и y = малая то F= очень большая
# Если х = большая и y = средняя то F= большая
# Если х = большая и y = большая то F= большая
# Если х = большая и y = очень большая то F= сильно большая
# Если х = большая и y = сильно большая то F= сильно большая
# Если х = очень большая и y = малая то F= большая
# Если х = очень большая и y = средняя то F= средняя
# Если х = очень большая и y = большая то F= большая
# Если х = очень большая и y = очень большая то F= очень большая
# Если х = очень большая и y = сильно большая то F= средняя
# Если х = сильно большая и y = очень малая то F= большая
# Если х = сильно большая и y = малая то F= малая
# Если х = сильно большая и y = средняя то F= средняя
# Если х = сильно большая и y = большая то F= большая
# Если х = сильно большая и y = очень большая то F= средняя
# Если х = сильно большая и y = сильно большая то F= очень малая

# %%
print("\033[1m" + "Мамдани для 9 термов" + "\033[0m")
for rangeX in rangesX_9:
  for rangeY in rangesY_9:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_9:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], rangeZ['term']))
# Out:
# Мамдани для 9 термов
# Если х = сильно малая и y = сильно малая то F= малая
# Если х = сильно малая и y = очень малая то F= сильно малая
# Если х = сильно малая и y = малая то F= очень малая
# Если х = сильно малая и y = ниже среднего то F= ниже среднего
# Если х = сильно малая и y = средняя то F= средняя
# Если х = сильно малая и y = выше среднего то F= средняя
# Если х = сильно малая и y = большая то F= малая
# Если х = сильно малая и y = очень большая то F= очень малая
# Если х = сильно малая и y = сильно большая то F= очень малая
# Если х = очень малая и y = малая то F= очень малая
# Если х = очень малая и y = ниже среднего то F= средняя
# Если х = очень малая и y = средняя то F= выше среднего
# Если х = очень малая и y = выше среднего то F= средняя
# Если х = очень малая и y = большая то F= малая
# Если х = очень малая и y = очень большая то F= малая
# Если х = очень малая и y = сильно большая то F= средняя
# Если х = малая и y = малая то F= ниже среднего
# Если х = малая и y = ниже среднего то F= выше среднего
# Если х = малая и y = средняя то F= выше среднего
# Если х = малая и y = выше среднего то F= средняя
# Если х = малая и y = большая то F= ниже среднего
# Если х = малая и y = очень большая то F= средняя
# Если х = малая и y = сильно большая то F= очень большая
# Если х = ниже среднего и y = очень малая то F= ниже среднего
# Если х = ниже среднего и y = малая то F= большая
# Если х = ниже среднего и y = ниже среднего то F= очень большая
# Если х = ниже среднего и y = средняя то F= выше среднего
# Если х = ниже среднего и y = выше среднего то F= средняя
# Если х = ниже среднего и y = большая то F= средняя
# Если х = ниже среднего и y = очень большая то F= очень большая
# Если х = средняя и y = сильно малая то F= ниже среднего
# Если х = средняя и y = очень малая то F= большая
# Если х = средняя и y = малая то F= сильно большая
# Если х = средняя и y = ниже среднего то F= очень большая
# Если х = средняя и y = средняя то F= выше среднего
# Если х = средняя и y = выше среднего то F= средняя
# Если х = средняя и y = выше среднего то F= выше среднего
# Если х = средняя и y = большая то F= большая
# Если х = выше среднего и y = сильно малая то F= сильно большая
# Если х = выше среднего и y = ниже среднего то F= большая
# Если х = выше среднего и y = средняя то F= средняя
# Если х = выше среднего и y = средняя то F= выше среднего
# Если х = выше среднего и y = выше среднего то F= выше среднего
# Если х = выше среднего и y = большая то F= очень большая
# Если х = выше среднего и y = очень большая то F= сильно большая
# Если х = выше среднего и y = сильно большая то F= очень большая
# Если х = большая и y = малая то F= очень большая
# Если х = большая и y = ниже среднего то F= выше среднего
# Если х = большая и y = средняя то F= средняя
# Если х = большая и y = выше среднего то F= выше среднего
# Если х = большая и y = большая то F= очень большая
# Если х = большая и y = очень большая то F= большая
# Если х = большая и y = сильно большая то F= средняя
# Если х = очень большая и y = малая то F= выше среднего
# Если х = очень большая и y = ниже среднего то F= ниже среднего
# Если х = очень большая и y = средняя то F= средняя
# Если х = очень большая и y = выше среднего то F= выше среднего
# Если х = очень большая и y = большая то F= выше среднего
# Если х = очень большая и y = очень большая то F= ниже среднего
# Если х = очень большая и y = сильно большая то F= очень малая
# Если х = сильно большая и y = очень малая то F= выше среднего
# Если х = сильно большая и y = малая то F= ниже среднего
# Если х = сильно большая и y = ниже среднего то F= малая
# Если х = сильно большая и y = средняя то F= средняя
# Если х = сильно большая и y = выше среднего то F= выше среднего
# Если х = сильно большая и y = большая то F= средняя
# Если х = сильно большая и y = очень большая то F= очень малая

# %%
print("\033[1m" + "Мамдани для 11 термов" + "\033[0m")
for rangeX in rangesX_11:
  for rangeY in rangesY_11:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_11:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], rangeZ['term']))
# Out:
# Мамдани для 11 термов
# Если х = сильно малая и y = сильно малая то F= выше малой
# Если х = сильно малая и y = очень малая то F= очень малая
# Если х = сильно малая и y = малая то F= сильно малая
# Если х = сильно малая и y = выше малой то F= малая
# Если х = сильно малая и y = ниже среднего то F= ниже среднего
# Если х = сильно малая и y = средняя то F= средняя
# Если х = сильно малая и y = выше среднего то F= средняя
# Если х = сильно малая и y = ниже большой то F= ниже среднего
# Если х = сильно малая и y = большая то F= малая
# Если х = сильно малая и y = очень большая то F= очень малая
# Если х = сильно малая и y = сильно большая то F= малая
# Если х = очень малая и y = сильно малая то F= сильно малая
# Если х = очень малая и y = малая то F= сильно малая
# Если х = очень малая и y = выше малой то F= выше малой
# Если х = очень малая и y = ниже среднего то F= средняя
# Если х = очень малая и y = средняя то F= выше среднего
# Если х = очень малая и y = выше среднего то F= средняя
# Если х = очень малая и y = ниже большой то F= выше малой
# Если х = очень малая и y = большая то F= малая
# Если х = очень малая и y = очень большая то F= выше малой
# Если х = очень малая и y = сильно большая то F= средняя
# Если х = малая и y = малая то F= очень малая
# Если х = малая и y = выше малой то F= ниже среднего
# Если х = малая и y = ниже среднего то F= выше среднего
# Если х = малая и y = средняя то F= выше среднего
# Если х = малая и y = выше среднего то F= средняя
# Если х = малая и y = ниже большой то F= выше малой
# Если х = малая и y = большая то F= выше малой
# Если х = малая и y = сильно большая то F= большая
# Если х = выше малой и y = очень малая то F= сильно малая
# Если х = выше малой и y = малая то F= ниже среднего
# Если х = выше малой и y = выше малой то F= ниже большой
# Если х = выше малой и y = ниже среднего то F= ниже большой
# Если х = выше малой и y = средняя то F= выше среднего
# Если х = выше малой и y = выше среднего то F= средняя
# Если х = выше малой и y = ниже большой то F= ниже среднего
# Если х = выше малой и y = большая то F= средняя
# Если х = выше малой и y = очень большая то F= большая
# Если х = ниже среднего и y = сильно малая то F= сильно малая
# Если х = ниже среднего и y = очень малая то F= ниже среднего
# Если х = ниже среднего и y = малая то F= ниже большой
# Если х = ниже среднего и y = выше малой то F= большая
# Если х = ниже среднего и y = ниже среднего то F= большая
# Если х = ниже среднего и y = средняя то F= выше среднего
# Если х = ниже среднего и y = выше среднего то F= средняя
# Если х = ниже среднего и y = большая то F= большая
# Если х = средняя и y = сильно малая то F= ниже среднего
# Если х = средняя и y = очень малая то F= ниже большой
# Если х = средняя и y = малая то F= сильно большая
# Если х = средняя и y = выше малой то F= очень большая
# Если х = средняя и y = ниже среднего то F= большая
# Если х = средняя и y = средняя то F= выше среднего
# Если х = средняя и y = ниже большой то F= ниже большой
# Если х = средняя и y = большая то F= очень большая
# Если х = выше среднего и y = сильно малая то F= очень большая
# Если х = выше среднего и y = выше малой то F= очень большая
# Если х = выше среднего и y = ниже среднего то F= ниже большой
# Если х = выше среднего и y = выше среднего то F= выше среднего
# Если х = выше среднего и y = ниже большой то F= большая
# Если х = выше среднего и y = большая то F= очень большая
# Если х = выше среднего и y = очень большая то F= сильно большая
# Если х = выше среднего и y = сильно большая то F= большая
# Если х = ниже большой и y = выше малой то F= большая
# Если х = ниже большой и y = средняя то F= средняя
# Если х = ниже большой и y = выше среднего то F= выше среднего
# Если х = ниже большой и y = ниже большой то F= большая
# Если х = ниже большой и y = большая то F= большая
# Если х = ниже большой и y = очень большая то F= ниже большой
# Если х = ниже большой и y = сильно большая то F= средняя
# Если х = большая и y = малая то F= большая
# Если х = большая и y = выше малой то F= выше среднего
# Если х = большая и y = ниже среднего то F= ниже среднего
# Если х = большая и y = средняя то F= средняя
# Если х = большая и y = выше среднего то F= выше среднего
# Если х = большая и y = ниже большой то F= ниже большой
# Если х = большая и y = большая то F= ниже большой
# Если х = большая и y = очень большая то F= ниже среднего
# Если х = большая и y = сильно большая то F= очень малая
# Если х = очень большая и y = очень малая то F= очень большая
# Если х = очень большая и y = выше малой то F= выше малой
# Если х = очень большая и y = ниже среднего то F= выше малой
# Если х = очень большая и y = средняя то F= средняя
# Если х = очень большая и y = выше среднего то F= выше среднего
# Если х = очень большая и y = ниже большой то F= выше среднего
# Если х = очень большая и y = большая то F= ниже среднего
# Если х = очень большая и y = очень большая то F= очень малая
# Если х = сильно большая и y = сильно малая то F= сильно большая
# Если х = сильно большая и y = очень малая то F= ниже большой
# Если х = сильно большая и y = малая то F= выше малой
# Если х = сильно большая и y = выше малой то F= малая
# Если х = сильно большая и y = ниже среднего то F= выше малой
# Если х = сильно большая и y = средняя то F= средняя
# Если х = сильно большая и y = выше среднего то F= выше среднего
# Если х = сильно большая и y = ниже большой то F= средняя
# Если х = сильно большая и y = большая то F= выше малой
# Если х = сильно большая и y = очень большая то F= сильно малая

# %%
def singleton(term, term_num):
  if term_num == 5:
    return terms5.index(term) - ((term_num - 1) / 2)
  elif term_num == 7:
    return terms7.index(term) - ((term_num - 1) / 2)
  elif term_num == 9:
    return terms9.index(term) - ((term_num - 1) / 2)
  elif term_num == 11:
    return terms11.index(term) - ((term_num - 1) / 2)

# %%
print("\033[1m" + "Синглтон для 5 термов" + "\033[0m")
for rangeX in rangesX_5:
  for rangeY in rangesY_5:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_5:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], singleton(rangeZ['term'], 5)))
# Out:
# Синглтон для 5 термов
# Если х = очень малая и y = очень малая то F= -2.0
# Если х = очень малая и y = малая то F= -2.0
# Если х = очень малая и y = средняя то F= 0.0
# Если х = очень малая и y = большая то F= 0.0
# Если х = очень малая и y = очень большая то F= -1.0
# Если х = малая и y = малая то F= -1.0
# Если х = малая и y = средняя то F= 1.0
# Если х = малая и y = большая то F= 0.0
# Если х = малая и y = очень большая то F= 0.0
# Если х = средняя и y = очень малая то F= -1.0
# Если х = средняя и y = малая то F= 2.0
# Если х = средняя и y = средняя то F= 1.0
# Если х = средняя и y = большая то F= 0.0
# Если х = большая и y = средняя то F= 0.0
# Если х = большая и y = большая то F= 1.0
# Если х = очень большая и y = малая то F= 1.0
# Если х = очень большая и y = средняя то F= 0.0
# Если х = очень большая и y = большая то F= 1.0
# Если х = очень большая и y = очень большая то F= 0.0
# Если х = очень большая и y = очень большая то F= 1.0

# %%
print("\033[1m" + "Синглтон для 7 термов" + "\033[0m")
for rangeX in rangesX_7:
  for rangeY in rangesY_7:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_7:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], singleton(rangeZ['term'], 7)))
# Out:
# Синглтон для 7 термов
# Если х = сильно малая и y = сильно малая то F= -2.0
# Если х = сильно малая и y = малая то F= -2.0
# Если х = сильно малая и y = средняя то F= 0.0
# Если х = сильно малая и y = большая то F= 0.0
# Если х = сильно малая и y = очень большая то F= -2.0
# Если х = сильно малая и y = сильно большая то F= -2.0
# Если х = очень малая и y = малая то F= -1.0
# Если х = очень малая и y = средняя то F= 1.0
# Если х = очень малая и y = большая то F= 0.0
# Если х = очень малая и y = очень большая то F= -1.0
# Если х = очень малая и y = сильно большая то F= 0.0
# Если х = малая и y = очень малая то F= -1.0
# Если х = малая и y = малая то F= 2.0
# Если х = малая и y = средняя то F= 1.0
# Если х = малая и y = большая то F= 0.0
# Если х = малая и y = очень большая то F= 1.0
# Если х = малая и y = сильно большая то F= 3.0
# Если х = средняя и y = сильно малая то F= -1.0
# Если х = средняя и y = очень малая то F= 2.0
# Если х = средняя и y = малая то F= 3.0
# Если х = средняя и y = средняя то F= 1.0
# Если х = средняя и y = большая то F= 1.0
# Если х = средняя и y = очень большая то F= 2.0
# Если х = большая и y = малая то F= 2.0
# Если х = большая и y = средняя то F= 1.0
# Если х = большая и y = большая то F= 1.0
# Если х = большая и y = очень большая то F= 3.0
# Если х = большая и y = сильно большая то F= 3.0
# Если х = очень большая и y = малая то F= 1.0
# Если х = очень большая и y = средняя то F= 0.0
# Если х = очень большая и y = большая то F= 1.0
# Если х = очень большая и y = очень большая то F= 2.0
# Если х = очень большая и y = сильно большая то F= 0.0
# Если х = сильно большая и y = очень малая то F= 1.0
# Если х = сильно большая и y = малая то F= -1.0
# Если х = сильно большая и y = средняя то F= 0.0
# Если х = сильно большая и y = большая то F= 1.0
# Если х = сильно большая и y = очень большая то F= 0.0
# Если х = сильно большая и y = сильно большая то F= -2.0

# %%
print("\033[1m" + "Синглтон для 9 термов" + "\033[0m")
for rangeX in rangesX_9:
  for rangeY in rangesY_9:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_9:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], singleton(rangeZ['term'], 9)))
# Out:
# Синглтон для 9 термов
# Если х = сильно малая и y = сильно малая то F= -2.0
# Если х = сильно малая и y = очень малая то F= -4.0
# Если х = сильно малая и y = малая то F= -3.0
# Если х = сильно малая и y = ниже среднего то F= -1.0
# Если х = сильно малая и y = средняя то F= 0.0
# Если х = сильно малая и y = выше среднего то F= 0.0
# Если х = сильно малая и y = большая то F= -2.0
# Если х = сильно малая и y = очень большая то F= -3.0
# Если х = сильно малая и y = сильно большая то F= -3.0
# Если х = очень малая и y = малая то F= -3.0
# Если х = очень малая и y = ниже среднего то F= 0.0
# Если х = очень малая и y = средняя то F= 1.0
# Если х = очень малая и y = выше среднего то F= 0.0
# Если х = очень малая и y = большая то F= -2.0
# Если х = очень малая и y = очень большая то F= -2.0
# Если х = очень малая и y = сильно большая то F= 0.0
# Если х = малая и y = малая то F= -1.0
# Если х = малая и y = ниже среднего то F= 1.0
# Если х = малая и y = средняя то F= 1.0
# Если х = малая и y = выше среднего то F= 0.0
# Если х = малая и y = большая то F= -1.0
# Если х = малая и y = очень большая то F= 0.0
# Если х = малая и y = сильно большая то F= 3.0
# Если х = ниже среднего и y = очень малая то F= -1.0
# Если х = ниже среднего и y = малая то F= 2.0
# Если х = ниже среднего и y = ниже среднего то F= 3.0
# Если х = ниже среднего и y = средняя то F= 1.0
# Если х = ниже среднего и y = выше среднего то F= 0.0
# Если х = ниже среднего и y = большая то F= 0.0
# Если х = ниже среднего и y = очень большая то F= 3.0
# Если х = средняя и y = сильно малая то F= -1.0
# Если х = средняя и y = очень малая то F= 2.0
# Если х = средняя и y = малая то F= 4.0
# Если х = средняя и y = ниже среднего то F= 3.0
# Если х = средняя и y = средняя то F= 1.0
# Если х = средняя и y = выше среднего то F= 0.0
# Если х = средняя и y = выше среднего то F= 1.0
# Если х = средняя и y = большая то F= 2.0
# Если х = выше среднего и y = сильно малая то F= 4.0
# Если х = выше среднего и y = ниже среднего то F= 2.0
# Если х = выше среднего и y = средняя то F= 0.0
# Если х = выше среднего и y = средняя то F= 1.0
# Если х = выше среднего и y = выше среднего то F= 1.0
# Если х = выше среднего и y = большая то F= 3.0
# Если х = выше среднего и y = очень большая то F= 4.0
# Если х = выше среднего и y = сильно большая то F= 3.0
# Если х = большая и y = малая то F= 3.0
# Если х = большая и y = ниже среднего то F= 1.0
# Если х = большая и y = средняя то F= 0.0
# Если х = большая и y = выше среднего то F= 1.0
# Если х = большая и y = большая то F= 3.0
# Если х = большая и y = очень большая то F= 2.0
# Если х = большая и y = сильно большая то F= 0.0
# Если х = очень большая и y = малая то F= 1.0
# Если х = очень большая и y = ниже среднего то F= -1.0
# Если х = очень большая и y = средняя то F= 0.0
# Если х = очень большая и y = выше среднего то F= 1.0
# Если х = очень большая и y = большая то F= 1.0
# Если х = очень большая и y = очень большая то F= -1.0
# Если х = очень большая и y = сильно большая то F= -3.0
# Если х = сильно большая и y = очень малая то F= 1.0
# Если х = сильно большая и y = малая то F= -1.0
# Если х = сильно большая и y = ниже среднего то F= -2.0
# Если х = сильно большая и y = средняя то F= 0.0
# Если х = сильно большая и y = выше среднего то F= 1.0
# Если х = сильно большая и y = большая то F= 0.0
# Если х = сильно большая и y = очень большая то F= -3.0

# %%
print("\033[1m" + "Синглтон для 11 термов" + "\033[0m")
for rangeX in rangesX_11:
  for rangeY in rangesY_11:
    x = (rangeX['start'] + rangeX['end']) / 2
    y = (rangeY['start'] + rangeY['end']) / 2
    z = y * math.sin(x + y)
    for rangeZ in rangesZ_11:
      if rangeZ['start'] < z and z < rangeZ['end']:
        print('Если х = {} и y = {} то F= {}'.format(rangeX['term'], rangeY['term'], singleton(rangeZ['term'], 11)))
# Out:
# Синглтон для 11 термов
# Если х = сильно малая и y = сильно малая то F= -2.0
# Если х = сильно малая и y = очень малая то F= -4.0
# Если х = сильно малая и y = малая то F= -5.0
# Если х = сильно малая и y = выше малой то F= -3.0
# Если х = сильно малая и y = ниже среднего то F= -1.0
# Если х = сильно малая и y = средняя то F= 0.0
# Если х = сильно малая и y = выше среднего то F= 0.0
# Если х = сильно малая и y = ниже большой то F= -1.0
# Если х = сильно малая и y = большая то F= -3.0
# Если х = сильно малая и y = очень большая то F= -4.0
# Если х = сильно малая и y = сильно большая то F= -3.0
# Если х = очень малая и y = сильно малая то F= -5.0
# Если х = очень малая и y = малая то F= -5.0
# Если х = очень малая и y = выше малой то F= -2.0
# Если х = очень малая и y = ниже среднего то F= 0.0
# Если х = очень малая и y = средняя то F= 1.0
# Если х = очень малая и y = выше среднего то F= 0.0
# Если х = очень малая и y = ниже большой то F= -2.0
# Если х = очень малая и y = большая то F= -3.0
# Если х = очень малая и y = очень большая то F= -2.0
# Если х = очень малая и y = сильно большая то F= 0.0
# Если х = малая и y = малая то F= -4.0
# Если х = малая и y = выше малой то F= -1.0
# Если х = малая и y = ниже среднего то F= 1.0
# Если х = малая и y = средняя то F= 1.0
# Если х = малая и y = выше среднего то F= 0.0
# Если х = малая и y = ниже большой то F= -2.0
# Если х = малая и y = большая то F= -2.0
# Если х = малая и y = сильно большая то F= 3.0
# Если х = выше малой и y = очень малая то F= -5.0
# Если х = выше малой и y = малая то F= -1.0
# Если х = выше малой и y = выше малой то F= 2.0
# Если х = выше малой и y = ниже среднего то F= 2.0
# Если х = выше малой и y = средняя то F= 1.0
# Если х = выше малой и y = выше среднего то F= 0.0
# Если х = выше малой и y = ниже большой то F= -1.0
# Если х = выше малой и y = большая то F= 0.0
# Если х = выше малой и y = очень большая то F= 3.0
# Если х = ниже среднего и y = сильно малая то F= -5.0
# Если х = ниже среднего и y = очень малая то F= -1.0
# Если х = ниже среднего и y = малая то F= 2.0
# Если х = ниже среднего и y = выше малой то F= 3.0
# Если х = ниже среднего и y = ниже среднего то F= 3.0
# Если х = ниже среднего и y = средняя то F= 1.0
# Если х = ниже среднего и y = выше среднего то F= 0.0
# Если х = ниже среднего и y = большая то F= 3.0
# Если х = средняя и y = сильно малая то F= -1.0
# Если х = средняя и y = очень малая то F= 2.0
# Если х = средняя и y = малая то F= 5.0
# Если х = средняя и y = выше малой то F= 4.0
# Если х = средняя и y = ниже среднего то F= 3.0
# Если х = средняя и y = средняя то F= 1.0
# Если х = средняя и y = ниже большой то F= 2.0
# Если х = средняя и y = большая то F= 4.0
# Если х = выше среднего и y = сильно малая то F= 4.0
# Если х = выше среднего и y = выше малой то F= 4.0
# Если х = выше среднего и y = ниже среднего то F= 2.0
# Если х = выше среднего и y = выше среднего то F= 1.0
# Если х = выше среднего и y = ниже большой то F= 3.0
# Если х = выше среднего и y = большая то F= 4.0
# Если х = выше среднего и y = очень большая то F= 5.0
# Если х = выше среднего и y = сильно большая то F= 3.0
# Если х = ниже большой и y = выше малой то F= 3.0
# Если х = ниже большой и y = средняя то F= 0.0
# Если х = ниже большой и y = выше среднего то F= 1.0
# Если х = ниже большой и y = ниже большой то F= 3.0
# Если х = ниже большой и y = большая то F= 3.0
# Если х = ниже большой и y = очень большая то F= 2.0
# Если х = ниже большой и y = сильно большая то F= 0.0
# Если х = большая и y = малая то F= 3.0
# Если х = большая и y = выше малой то F= 1.0
# Если х = большая и y = ниже среднего то F= -1.0
# Если х = большая и y = средняя то F= 0.0
# Если х = большая и y = выше среднего то F= 1.0
# Если х = большая и y = ниже большой то F= 2.0
# Если х = большая и y = большая то F= 2.0
# Если х = большая и y = очень большая то F= -1.0
# Если х = большая и y = сильно большая то F= -4.0
# Если х = очень большая и y = очень малая то F= 4.0
# Если х = очень большая и y = выше малой то F= -2.0
# Если х = очень большая и y = ниже среднего то F= -2.0
# Если х = очень большая и y = средняя то F= 0.0
# Если х = очень большая и y = выше среднего то F= 1.0
# Если х = очень большая и y = ниже большой то F= 1.0
# Если х = очень большая и y = большая то F= -1.0
# Если х = очень большая и y = очень большая то F= -4.0
# Если х = сильно большая и y = сильно малая то F= 5.0
# Если х = сильно большая и y = очень малая то F= 2.0
# Если х = сильно большая и y = малая то F= -2.0
# Если х = сильно большая и y = выше малой то F= -3.0
# Если х = сильно большая и y = ниже среднего то F= -2.0
# Если х = сильно большая и y = средняя то F= 0.0
# Если х = сильно большая и y = выше среднего то F= 1.0
# Если х = сильно большая и y = ниже большой то F= 0.0
# Если х = сильно большая и y = большая то F= -2.0
# Если х = сильно большая и y = очень большая то F= -5.0
